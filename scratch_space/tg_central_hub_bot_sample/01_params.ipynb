# %% [markdown]
# # Sample of the `tg_central_hub_bot` params

# %% [markdown]
# Remember that the params are hardcoded values of the config,
# the config is the structure that holds the params.
#
# Configs can be imported from anywhere,
# actual params should only be imported from
# `tg_central_hub_bot.params.tg_central_hub_bot_params.py` and used in the project.

# %% [markdown]
# ## Import

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from loguru import logger as lg
from rich import get_console
from rich import print as rprint
from rich.console import Console

# some magic to make rich work in jupyter
# https://github.com/Textualize/rich/issues/3483
# enable it for every cell output with %load_ext rich
console: Console = get_console()
console.is_jupyter = False

# %%
from tg_central_hub_bot.params.tg_central_hub_bot_params import (
    get_tg_central_hub_bot_params,
)

# %% [markdown]
# ## Params sample

# %%
tg_central_hub_bot_params = get_tg_central_hub_bot_params()
rprint(tg_central_hub_bot_params)

# %%
# get some configs from params
sample_config = tg_central_hub_bot_params.sample.to_config()
rprint(sample_config)

# note that only the top level is converted to dict,
# nested models remain as models
sample_config_kw = sample_config.to_kw()
rprint(sample_config_kw)
rprint(type(sample_config_kw))
rprint(type(sample_config_kw["nested_model"]))
